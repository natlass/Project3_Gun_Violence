# %%
import pandas as pd
import numpy as np
import pymongo

# %%
df=pd.read_csv("gun-violence-data_01-2013_03-2018.csv.zip")

# %%
df.head()
# Out:
#    incident_id        date           state city_or_county  \
# 0       461105  2013-01-01    Pennsylvania     Mckeesport
# 1       460726  2013-01-01      California      Hawthorne
# 2       478855  2013-01-01            Ohio         Lorain
# 3       478925  2013-01-05        Colorado         Aurora
# 4       478959  2013-01-07  North Carolina     Greensboro
#
#                                      address  n_killed  n_injured  \
# 0  1506 Versailles Avenue and Coursin Street         0          4
# 1               13500 block of Cerise Avenue         1          3
# 2                      1776 East 28th Street         1          3
# 3           16000 block of East Ithaca Place         4          0
# 4                  307 Mourning Dove Terrace         2          2
#
#                                         incident_url  \
# 0  http://www.gunviolencearchive.org/incident/461105
# 1  http://www.gunviolencearchive.org/incident/460726
# 2  http://www.gunviolencearchive.org/incident/478855
# 3  http://www.gunviolencearchive.org/incident/478925
# 4  http://www.gunviolencearchive.org/incident/478959
#
#                                           source_url  \
# 0  http://www.post-gazette.com/local/south/2013/0...
# 1  http://www.dailybulletin.com/article/zz/201301...
# 2  http://chronicle.northcoastnow.com/2013/02/14/...
# 3  http://www.dailydemocrat.com/20130106/aurora-s...
# 4  http://www.journalnow.com/news/local/article_d...
#
#    incident_url_fields_missing  ...                    participant_age  \
# 0                        False  ...                              0::20
# 1                        False  ...                              0::20
# 2                        False  ...  0::25||1::31||2::33||3::34||4::33
# 3                        False  ...         0::29||1::33||2::56||3::33
# 4                        False  ...         0::18||1::46||2::14||3::47
#
#                                participant_age_group  \
# 0  0::Adult 18+||1::Adult 18+||2::Adult 18+||3::A...
# 1  0::Adult 18+||1::Adult 18+||2::Adult 18+||3::A...
# 2  0::Adult 18+||1::Adult 18+||2::Adult 18+||3::A...
# 3  0::Adult 18+||1::Adult 18+||2::Adult 18+||3::A...
# 4  0::Adult 18+||1::Adult 18+||2::Teen 12-17||3::...
#
#                             participant_gender  \
# 0         0::Male||1::Male||3::Male||4::Female
# 1                                      0::Male
# 2  0::Male||1::Male||2::Male||3::Male||4::Male
# 3         0::Female||1::Male||2::Male||3::Male
# 4       0::Female||1::Male||2::Male||3::Female
#
#                                     participant_name  \
# 0                                     0::Julian Sims
# 1                                  0::Bernard Gillis
# 2  0::Damien Bell||1::Desmen Noble||2::Herman Sea...
# 3  0::Stacie Philbrook||1::Christopher Ratliffe||...
# 4  0::Danielle Imani Jameison||1::Maurice Eugene ...
#
#    participant_relationship  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                 3::Family
#
#                                   participant_status  \
# 0  0::Arrested||1::Injured||2::Injured||3::Injure...
# 1      0::Killed||1::Injured||2::Injured||3::Injured
# 2  0::Injured, Unharmed, Arrested||1::Unharmed, A...
# 3         0::Killed||1::Killed||2::Killed||3::Killed
# 4       0::Injured||1::Injured||2::Killed||3::Killed
#
#                                     participant_type  \
# 0  0::Victim||1::Victim||2::Victim||3::Victim||4:...
# 1  0::Victim||1::Victim||2::Victim||3::Victim||4:...
# 2  0::Subject-Suspect||1::Subject-Suspect||2::Vic...
# 3  0::Victim||1::Victim||2::Victim||3::Subject-Su...
# 4  0::Victim||1::Victim||2::Victim||3::Subject-Su...
#
#                                              sources state_house_district  \
# 0  http://pittsburgh.cbslocal.com/2013/01/01/4-pe...                  NaN
# 1  http://losangeles.cbslocal.com/2013/01/01/man-...                 62.0
# 2  http://www.morningjournal.com/general-news/201...                 56.0
# 3  http://denver.cbslocal.com/2013/01/06/officer-...                 40.0
# 4  http://myfox8.com/2013/01/08/update-mother-sho...                 62.0
#
#   state_senate_district
# 0                   NaN
# 1                  35.0
# 2                  13.0
# 3                  28.0
# 4                  27.0
#
# [5 rows x 29 columns]

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
# Declare the database
db = client.guns_db
# Declare the collection
guns = db.guns

# %%
client.list_database_names()
# Out:
# ['admin',
#  'classDB',
#  'config',
#  'craigslist_db',
#  'dumpster_db',
#  'guns_db',
#  'guns_db2',
#  'local',
#  'mars_db',
#  'store_inventory',
#  'team_db',
#  'travel_db']

# %%
df.columns
# Out:
# Index(['incident_id', 'date', 'state', 'city_or_county', 'address', 'n_killed',
#        'n_injured', 'incident_url', 'source_url',
#        'incident_url_fields_missing', 'congressional_district', 'gun_stolen',
#        'gun_type', 'incident_characteristics', 'latitude',
#        'location_description', 'longitude', 'n_guns_involved', 'notes',
#        'participant_age', 'participant_age_group', 'participant_gender',
#        'participant_name', 'participant_relationship', 'participant_status',
#        'participant_type', 'sources', 'state_house_district',
#        'state_senate_district'],
#       dtype='object')

# %%
dropped_columns=df.drop(columns=['city_or_county','address','incident_url','source_url','incident_url_fields_missing','congressional_district','gun_stolen','gun_type','incident_characteristics','location_description','n_guns_involved','notes','participant_age','participant_age_group','participant_name','participant_relationship','participant_status','participant_type','sources','state_house_district','state_senate_district','participant_gender'])

# %%
dropped_columns
# Out:
#         incident_id        date           state  n_killed  n_injured  \
# 0            461105  2013-01-01    Pennsylvania         0          4
# 1            460726  2013-01-01      California         1          3
# 2            478855  2013-01-01            Ohio         1          3
# 3            478925  2013-01-05        Colorado         4          0
# 4            478959  2013-01-07  North Carolina         2          2
# ...             ...         ...             ...       ...        ...
# 239672      1083142  2018-03-31       Louisiana         0          0
# 239673      1083139  2018-03-31       Louisiana         1          0
# 239674      1083151  2018-03-31       Louisiana         0          1
# 239675      1082514  2018-03-31           Texas         1          0
# 239676      1081940  2018-03-31           Maine         2          0
#
#         latitude  longitude
# 0        40.3467   -79.8559
# 1        33.9090  -118.3330
# 2        41.4455   -82.1377
# 3        39.6518  -104.8020
# 4        36.1140   -79.9569
# ...          ...        ...
# 239672       NaN        NaN
# 239673   31.7537   -93.0836
# 239674   29.9239   -90.0442
# 239675   29.7201   -95.6110
# 239676   44.7293   -69.7691
#
# [239677 rows x 7 columns]

# %%
clean = dropped_columns.loc[(dropped_columns['state'] == "Pennsylvania") | (dropped_columns['state'] == "Tennessee") | (dropped_columns['state'] == "California")]

# %%
clean
# Out:
#         incident_id        date         state  n_killed  n_injured  latitude  \
# 0            461105  2013-01-01  Pennsylvania         0          4   40.3467
# 1            460726  2013-01-01    California         1          3   33.9090
# 8            479389  2013-01-21    California         0          4   37.9656
# 10           491674  2013-01-23     Tennessee         1          3   35.0221
# 15           479573  2013-02-02     Tennessee         0          5   35.0803
# ...             ...         ...           ...       ...        ...       ...
# 239655      1082089  2018-03-31    California         0          0   32.8936
# 239657      1082394  2018-03-31    California         0          0   35.5019
# 239658      1082392  2018-03-31    California         1          0       NaN
# 239660      1082091  2018-03-31    California         2          0   37.9478
# 239667      1082234  2018-03-31     Tennessee         0          1   35.2045
#
#         longitude
# 0        -79.8559
# 1       -118.3330
# 8       -121.7180
# 10       -85.2697
# 15       -89.8871
# ...           ...
# 239655  -117.1360
# 239657  -119.2830
# 239658        NaN
# 239660  -121.3140
# 239667   -89.9872
#
# [32861 rows x 7 columns]

# %%
guns_df=clean.dropna()

# %%
gun=guns_df['date'] >= '2015-01-01'

# %%
guns_df= guns_df[gun]

# %%
guns_df['date']=pd.to_datetime(guns_df['date'])
guns_df['date']
# Out:
# 52144    2015-01-01
# 52158    2015-01-01
# 52164    2015-01-01
# 52165    2015-01-01
# 52171    2015-01-01
#             ...
# 239650   2018-03-31
# 239655   2018-03-31
# 239657   2018-03-31
# 239660   2018-03-31
# 239667   2018-03-31
# Name: date, Length: 24306, dtype: datetime64[ns]

# %%
guns_df['year']= guns_df['date'].dt.year
guns_df
# Out:
#         incident_id       date         state  n_killed  n_injured  latitude  \
# 52144        272502 2015-01-01     Tennessee         0          1   35.0064
# 52158        271979 2015-01-01    California         1          2   34.0322
# 52164        273937 2015-01-01  Pennsylvania         1          0   39.8449
# 52165        272960 2015-01-01  Pennsylvania         1          0   39.8406
# 52171        272551 2015-01-01    California         1          0   37.3006
# ...             ...        ...           ...       ...        ...       ...
# 239650      1082266 2018-03-31    California         1          0   34.5713
# 239655      1082089 2018-03-31    California         0          0   32.8936
# 239657      1082394 2018-03-31    California         0          0   35.5019
# 239660      1082091 2018-03-31    California         2          0   37.9478
# 239667      1082234 2018-03-31     Tennessee         0          1   35.2045
#
#         longitude  year
# 52144    -85.3179  2015
# 52158   -117.3260  2015
# 52164    -75.3816  2015
# 52165    -75.3976  2015
# 52171   -120.4980  2015
# ...           ...   ...
# 239650  -118.0450  2018
# 239655  -117.1360  2018
# 239657  -119.2830  2018
# 239660  -121.3140  2018
# 239667   -89.9872  2018
#
# [24306 rows x 8 columns]

# %%
guns_df['combined'] = list(zip(guns_df.latitude, guns_df.longitude))
guns_df.head()
# Out:
#        incident_id       date         state  n_killed  n_injured  latitude  \
# 52144       272502 2015-01-01     Tennessee         0          1   35.0064
# 52158       271979 2015-01-01    California         1          2   34.0322
# 52164       273937 2015-01-01  Pennsylvania         1          0   39.8449
# 52165       272960 2015-01-01  Pennsylvania         1          0   39.8406
# 52171       272551 2015-01-01    California         1          0   37.3006
#
#        longitude  year                        combined
# 52144   -85.3179  2015             (35.0064, -85.3179)
# 52158  -117.3260  2015  (34.0322, -117.32600000000001)
# 52164   -75.3816  2015             (39.8449, -75.3816)
# 52165   -75.3976  2015             (39.8406, -75.3976)
# 52171  -120.4980  2015  (37.3006, -120.49799999999999)

# %%
guns_df.dtypes
# Out:
# incident_id             int64
# date           datetime64[ns]
# state                  object
# n_killed                int64
# n_injured               int64
# latitude              float64
# longitude             float64
# year                    int64
# combined               object
# dtype: object

# %%
guns_df['year'] = guns_df['year'].astype(str)
print(guns_df['year'])
# Out:
# 52144     2015
# 52158     2015
# 52164     2015
# 52165     2015
# 52171     2015
#           ...
# 239650    2018
# 239655    2018
# 239657    2018
# 239660    2018
# 239667    2018
# Name: year, Length: 24306, dtype: object

# %%
guns_df.to_dict('records')
# Out:
# [{'incident_id': 272502,
#   'date': Timestamp('2015-01-01 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 35.0064,
#   'longitude': -85.3179,
#   'year': '2015',
#   'combined': (35.0064, -85.3179)},
#  {'incident_id': 271979,
#   'date': Timestamp('2015-01-01 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 2,
#   'latitude': 34.0322,
#   'longitude': -117.32600000000001,
#   'year': '2015',
#   'combined': (34.0322, -117.32600000000001)},
#  {'incident_id': 273937,
#   'date': Timestamp('2015-01-01 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 39.8449,
#   'longitude': -75.3816,
#   'year': '2015',
#   'combined': (39.8449, -75.3816)},
#  {'incident_id': 272960,
#   'date': Timestamp('2015-01-01 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 39.8406,
#   'longitude': -75.3976,
#   'year': '2015',
#   'combined': (39.8406, -75.3976)},
#  {'incident_id': 272551,
#   'date': Timestamp('2015-01-01 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 37.3006,
#   'longitude': -120.49799999999999,
#   'year': '2015',
#   'combined': (37.3006, -120.49799999999999)},
#  {'incident_id': 272555,
#   'date': Timestamp('2015-01-01 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 36.6121,
#   'longitude': -121.836,
#   'year': '2015',
#   'combined': (36.6121, -121.836)},
#  {'incident_id': 273336,
#   'date': Timestamp('2015-01-01 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 39.9195,
#   'longitude': -75.2309,
#   'year': '2015',
#   'combined': (39.9195, -75.2309)},
#  {'incident_id': 272016,
#   'date': Timestamp('2015-01-01 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 5,
#   'latitude': 35.1489,
#   'longitude': -90.0461,
#   'year': '2015',
#   'combined': (35.1489, -90.0461)},
#  {'incident_id': 271970,
#   'date': Timestamp('2015-01-01 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 33.9327,
#   'longitude': -118.102,
#   'year': '2015',
#   'combined': (33.9327, -118.102)},
#  {'incident_id': 271975,
#   'date': Timestamp('2015-01-01 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 2,
#   'latitude': 37.3339,
#   'longitude': -121.855,
#   'year': '2015',
#   'combined': (37.3339, -121.855)},
#  {'incident_id': 275619,
#   'date': Timestamp('2015-01-01 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 1,
#   'latitude': 33.7429,
#   'longitude': -116.274,
#   'year': '2015',
#   'combined': (33.7429, -116.274)},
#  {'incident_id': 272495,
#   'date': Timestamp('2015-01-01 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 1,
#   'n_injured': 1,
#   'latitude': 36.1686,
#   'longitude': -87.0452,
#   'year': '2015',
#   'combined': (36.1686, -87.0452)},
#  {'incident_id': 271981,
#   'date': Timestamp('2015-01-01 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 38.66,
#   'longitude': -121.331,
#   'year': '2015',
#   'combined': (38.66, -121.331)},
#  {'incident_id': 276639,
#   'date': Timestamp('2015-01-01 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 1,
#   'latitude': 37.2991,
#   'longitude': -121.823,
#   'year': '2015',
#   'combined': (37.2991, -121.823)},
#  {'incident_id': 283479,
#   'date': Timestamp('2015-01-01 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 35.0456,
#   'longitude': -85.3083,
#   'year': '2015',
#   'combined': (35.0456, -85.3083)},
#  {'incident_id': 273083,
#   'date': Timestamp('2015-01-01 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 35.0228,
#   'longitude': -89.8631,
#   'year': '2015',
#   'combined': (35.0228, -89.8631)},
#  {'incident_id': 272030,
#   'date': Timestamp('2015-01-01 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 36.6133,
#   'longitude': -87.4187,
#   'year': '2015',
#   'combined': (36.6133, -87.4187)},
#  {'incident_id': 272041,
#   'date': Timestamp('2015-01-01 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 35.0135,
#   'longitude': -85.2266,
#   'year': '2015',
#   'combined': (35.0135, -85.2266)},
#  {'incident_id': 271986,
#   'date': Timestamp('2015-01-01 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 37.9624,
#   'longitude': -121.288,
#   'year': '2015',
#   'combined': (37.9624, -121.288)},
#  {'incident_id': 272526,
#   'date': Timestamp('2015-01-01 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 36.7307,
#   'longitude': -119.76899999999999,
#   'year': '2015',
#   'combined': (36.7307, -119.76899999999999)},
#  {'incident_id': 283487,
#   'date': Timestamp('2015-01-01 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 35.2823,
#   'longitude': -119.005,
#   'year': '2015',
#   'combined': (35.2823, -119.005)},
#  {'incident_id': 272165,
#   'date': Timestamp('2015-01-01 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 37.7881,
#   'longitude': -122.395,
#   'year': '2015',
#   'combined': (37.7881, -122.395)},
#  {'incident_id': 272531,
#   'date': Timestamp('2015-01-01 00:00:00'),
#   'state': 'California',
#   'n_killed': 4,
#   'n_injured': 0,
#   'latitude': 37.6774,
#   'longitude': -120.961,
#   'year': '2015',
#   'combined': (37.6774, -120.961)},
#  {'incident_id': 274489,
#   'date': Timestamp('2015-01-01 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 33.9527,
#   'longitude': -116.473,
#   'year': '2015',
#   'combined': (33.9527, -116.473)},
#  {'incident_id': 272043,
#   'date': Timestamp('2015-01-01 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 35.0027,
#   'longitude': -85.3109,
#   'year': '2015',
#   'combined': (35.0027, -85.3109)},
#  {'incident_id': 272045,
#   'date': Timestamp('2015-01-01 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 35.0124,
#   'longitude': -85.2261,
#   'year': '2015',
#   'combined': (35.0124, -85.2261)},
#  {'incident_id': 273497,
#   'date': Timestamp('2015-01-01 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 37.3103,
#   'longitude': -120.48100000000001,
#   'year': '2015',
#   'combined': (37.3103, -120.48100000000001)},
#  {'incident_id': 273910,
#   'date': Timestamp('2015-01-01 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 35.0276,
#   'longitude': -85.2548,
#   'year': '2015',
#   'combined': (35.0276, -85.2548)},
#  {'incident_id': 272556,
#   'date': Timestamp('2015-01-01 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 34.0558,
#   'longitude': -117.72200000000001,
#   'year': '2015',
#   'combined': (34.0558, -117.72200000000001)},
#  {'incident_id': 272958,
#   'date': Timestamp('2015-01-01 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 40.0391,
#   'longitude': -75.1253,
#   'year': '2015',
#   'combined': (40.0391, -75.1253)},
#  {'incident_id': 272956,
#   'date': Timestamp('2015-01-01 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 40.234,
#   'longitude': -76.8386,
#   'year': '2015',
#   'combined': (40.234, -76.8386)},
#  {'incident_id': 273324,
#   'date': Timestamp('2015-01-02 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 40.454,
#   'longitude': -80.0263,
#   'year': '2015',
#   'combined': (40.454, -80.0263)},
#  {'incident_id': 272511,
#   'date': Timestamp('2015-01-02 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 37.7937,
#   'longitude': -122.236,
#   'year': '2015',
#   'combined': (37.7937, -122.236)},
#  {'incident_id': 273249,
#   'date': Timestamp('2015-01-02 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 36.7501,
#   'longitude': -119.84899999999999,
#   'year': '2015',
#   'combined': (36.7501, -119.84899999999999)},
#  {'incident_id': 283457,
#   'date': Timestamp('2015-01-02 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 40.2132,
#   'longitude': -76.6156,
#   'year': '2015',
#   'combined': (40.2132, -76.6156)},
#  {'incident_id': 273294,
#   'date': Timestamp('2015-01-02 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 2,
#   'latitude': 39.2025,
#   'longitude': -121.145,
#   'year': '2015',
#   'combined': (39.2025, -121.145)},
#  {'incident_id': 276481,
#   'date': Timestamp('2015-01-02 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 40.2558,
#   'longitude': -76.8416,
#   'year': '2015',
#   'combined': (40.2558, -76.8416)},
#  {'incident_id': 273070,
#   'date': Timestamp('2015-01-02 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 36.1518,
#   'longitude': -86.6492,
#   'year': '2015',
#   'combined': (36.1518, -86.6492)},
#  {'incident_id': 272498,
#   'date': Timestamp('2015-01-02 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 35.9966,
#   'longitude': -83.8808,
#   'year': '2015',
#   'combined': (35.9966, -83.8808)},
#  {'incident_id': 273686,
#   'date': Timestamp('2015-01-02 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 40.5195,
#   'longitude': -80.0399,
#   'year': '2015',
#   'combined': (40.5195, -80.0399)},
#  {'incident_id': 276249,
#   'date': Timestamp('2015-01-02 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 37.7296,
#   'longitude': -122.2,
#   'year': '2015',
#   'combined': (37.7296, -122.2)},
#  {'incident_id': 273270,
#   'date': Timestamp('2015-01-02 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 36.6041,
#   'longitude': -121.833,
#   'year': '2015',
#   'combined': (36.6041, -121.833)},
#  {'incident_id': 273331,
#   'date': Timestamp('2015-01-02 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 40.639,
#   'longitude': -79.8461,
#   'year': '2015',
#   'combined': (40.639, -79.8461)},
#  {'incident_id': 273329,
#   'date': Timestamp('2015-01-02 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 40.065,
#   'longitude': -75.1458,
#   'year': '2015',
#   'combined': (40.065, -75.1458)},
#  {'incident_id': 273313,
#   'date': Timestamp('2015-01-02 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 33.9261,
#   'longitude': -116.916,
#   'year': '2015',
#   'combined': (33.9261, -116.916)},
#  {'incident_id': 273335,
#   'date': Timestamp('2015-01-02 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 40.0257,
#   'longitude': -75.1659,
#   'year': '2015',
#   'combined': (40.0257, -75.1659)},
#  {'incident_id': 272513,
#   'date': Timestamp('2015-01-02 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 37.7604,
#   'longitude': -122.19,
#   'year': '2015',
#   'combined': (37.7604, -122.19)},
#  {'incident_id': 272908,
#   'date': Timestamp('2015-01-02 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 33.876,
#   'longitude': -118.22399999999999,
#   'year': '2015',
#   'combined': (33.876, -118.22399999999999)},
#  {'incident_id': 273735,
#   'date': Timestamp('2015-01-03 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 3,
#   'n_injured': 0,
#   'latitude': 40.3187,
#   'longitude': -77.1393,
#   'year': '2015',
#   'combined': (40.3187, -77.1393)},
#  {'incident_id': 273495,
#   'date': Timestamp('2015-01-03 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 36.7504,
#   'longitude': -119.79700000000001,
#   'year': '2015',
#   'combined': (36.7504, -119.79700000000001)},
#  {'incident_id': 273493,
#   'date': Timestamp('2015-01-03 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 37.0428,
#   'longitude': -122.027,
#   'year': '2015',
#   'combined': (37.0428, -122.027)},
#  {'incident_id': 273086,
#   'date': Timestamp('2015-01-03 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 35.9725,
#   'longitude': -83.8927,
#   'year': '2015',
#   'combined': (35.9725, -83.8927)},
#  {'incident_id': 273246,
#   'date': Timestamp('2015-01-03 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 35.3399,
#   'longitude': -119.02600000000001,
#   'year': '2015',
#   'combined': (35.3399, -119.02600000000001)},
#  {'incident_id': 273257,
#   'date': Timestamp('2015-01-03 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 3,
#   'latitude': 33.8488,
#   'longitude': -118.198,
#   'year': '2015',
#   'combined': (33.8488, -118.198)},
#  {'incident_id': 273658,
#   'date': Timestamp('2015-01-03 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 0,
#   'n_injured': 2,
#   'latitude': 39.9729,
#   'longitude': -75.2151,
#   'year': '2015',
#   'combined': (39.9729, -75.2151)},
#  {'incident_id': 274177,
#   'date': Timestamp('2015-01-03 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 39.9987,
#   'longitude': -75.1782,
#   'year': '2015',
#   'combined': (39.9987, -75.1782)},
#  {'incident_id': 273721,
#   'date': Timestamp('2015-01-03 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 39.9544,
#   'longitude': -75.2301,
#   'year': '2015',
#   'combined': (39.9544, -75.2301)},
#  {'incident_id': 273637,
#   'date': Timestamp('2015-01-03 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 41.2404,
#   'longitude': -75.9446,
#   'year': '2015',
#   'combined': (41.2404, -75.9446)},
#  {'incident_id': 273383,
#   'date': Timestamp('2015-01-03 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 38.1409,
#   'longitude': -122.25200000000001,
#   'year': '2015',
#   'combined': (38.1409, -122.25200000000001)},
#  {'incident_id': 273384,
#   'date': Timestamp('2015-01-03 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 41.2589,
#   'longitude': -76.1042,
#   'year': '2015',
#   'combined': (41.2589, -76.1042)},
#  {'incident_id': 278471,
#   'date': Timestamp('2015-01-03 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 33.7394,
#   'longitude': -117.912,
#   'year': '2015',
#   'combined': (33.7394, -117.912)},
#  {'incident_id': 273590,
#   'date': Timestamp('2015-01-03 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 34.0812,
#   'longitude': -118.29799999999999,
#   'year': '2015',
#   'combined': (34.0812, -118.29799999999999)},
#  {'incident_id': 273589,
#   'date': Timestamp('2015-01-03 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 33.9776,
#   'longitude': -118.255,
#   'year': '2015',
#   'combined': (33.9776, -118.255)},
#  {'incident_id': 273431,
#   'date': Timestamp('2015-01-03 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 34.0522,
#   'longitude': -118.244,
#   'year': '2015',
#   'combined': (34.0522, -118.244)},
#  {'incident_id': 273727,
#   'date': Timestamp('2015-01-04 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 39.9721,
#   'longitude': -75.2337,
#   'year': '2015',
#   'combined': (39.9721, -75.2337)},
#  {'incident_id': 273800,
#   'date': Timestamp('2015-01-04 00:00:00'),
#   'state': 'California',
#   'n_killed': 3,
#   'n_injured': 0,
#   'latitude': 33.8232,
#   'longitude': -116.51700000000001,
#   'year': '2015',
#   'combined': (33.8232, -116.51700000000001)},
#  {'incident_id': 274935,
#   'date': Timestamp('2015-01-04 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 0,
#   'n_injured': 2,
#   'latitude': 40.1427,
#   'longitude': -79.8664,
#   'year': '2015',
#   'combined': (40.1427, -79.8664)},
#  {'incident_id': 274933,
#   'date': Timestamp('2015-01-04 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 40.4219,
#   'longitude': -79.8934,
#   'year': '2015',
#   'combined': (40.4219, -79.8934)},
#  {'incident_id': 274924,
#   'date': Timestamp('2015-01-04 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 1,
#   'n_injured': 2,
#   'latitude': 40.0321,
#   'longitude': -76.3162,
#   'year': '2015',
#   'combined': (40.0321, -76.3162)},
#  {'incident_id': 274399,
#   'date': Timestamp('2015-01-04 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 36.7865,
#   'longitude': -119.844,
#   'year': '2015',
#   'combined': (36.7865, -119.844)},
#  {'incident_id': 274382,
#   'date': Timestamp('2015-01-04 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 40.3236,
#   'longitude': -123.92299999999999,
#   'year': '2015',
#   'combined': (40.3236, -123.92299999999999)},
#  {'incident_id': 275051,
#   'date': Timestamp('2015-01-04 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 37.7872,
#   'longitude': -122.41,
#   'year': '2015',
#   'combined': (37.7872, -122.41)},
#  {'incident_id': 274396,
#   'date': Timestamp('2015-01-04 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 36.0692,
#   'longitude': -119.03299999999999,
#   'year': '2015',
#   'combined': (36.0692, -119.03299999999999)},
#  {'incident_id': 273818,
#   'date': Timestamp('2015-01-04 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 38.0336,
#   'longitude': -121.294,
#   'year': '2015',
#   'combined': (38.0336, -121.294)},
#  {'incident_id': 791126,
#   'date': Timestamp('2015-01-04 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 37.7621,
#   'longitude': -122.42200000000001,
#   'year': '2015',
#   'combined': (37.7621, -122.42200000000001)},
#  {'incident_id': 274406,
#   'date': Timestamp('2015-01-04 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 33.8545,
#   'longitude': -117.315,
#   'year': '2015',
#   'combined': (33.8545, -117.315)},
#  {'incident_id': 273815,
#   'date': Timestamp('2015-01-04 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 2,
#   'latitude': 38.4084,
#   'longitude': -121.391,
#   'year': '2015',
#   'combined': (38.4084, -121.391)},
#  {'incident_id': 273739,
#   'date': Timestamp('2015-01-04 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 40.0084,
#   'longitude': -75.1438,
#   'year': '2015',
#   'combined': (40.0084, -75.1438)},
#  {'incident_id': 274855,
#   'date': Timestamp('2015-01-04 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 34.4921,
#   'longitude': -118.62799999999999,
#   'year': '2015',
#   'combined': (34.4921, -118.62799999999999)},
#  {'incident_id': 290075,
#   'date': Timestamp('2015-01-04 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 40.1257,
#   'longitude': -79.8688,
#   'year': '2015',
#   'combined': (40.1257, -79.8688)},
#  {'incident_id': 276551,
#   'date': Timestamp('2015-01-04 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 36.7479,
#   'longitude': -119.79899999999999,
#   'year': '2015',
#   'combined': (36.7479, -119.79899999999999)},
#  {'incident_id': 274938,
#   'date': Timestamp('2015-01-04 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 40.7956,
#   'longitude': -75.862,
#   'year': '2015',
#   'combined': (40.7956, -75.862)},
#  {'incident_id': 277008,
#   'date': Timestamp('2015-01-04 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 33.9464,
#   'longitude': -118.287,
#   'year': '2015',
#   'combined': (33.9464, -118.287)},
#  {'incident_id': 273586,
#   'date': Timestamp('2015-01-04 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 32.5454,
#   'longitude': -117.04,
#   'year': '2015',
#   'combined': (32.5454, -117.04)},
#  {'incident_id': 274592,
#   'date': Timestamp('2015-01-05 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 1,
#   'n_injured': 2,
#   'latitude': 36.3471,
#   'longitude': -88.8484,
#   'year': '2015',
#   'combined': (36.3471, -88.8484)},
#  {'incident_id': 275047,
#   'date': Timestamp('2015-01-05 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 33.808,
#   'longitude': -118.16799999999999,
#   'year': '2015',
#   'combined': (33.808, -118.16799999999999)},
#  {'incident_id': 275224,
#   'date': Timestamp('2015-01-05 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 36.2986,
#   'longitude': -86.7213,
#   'year': '2015',
#   'combined': (36.2986, -86.7213)},
#  {'incident_id': 273804,
#   'date': Timestamp('2015-01-05 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 34.0998,
#   'longitude': -118.33,
#   'year': '2015',
#   'combined': (34.0998, -118.33)},
#  {'incident_id': 274588,
#   'date': Timestamp('2015-01-05 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 36.2103,
#   'longitude': -86.2827,
#   'year': '2015',
#   'combined': (36.2103, -86.2827)},
#  {'incident_id': 273979,
#   'date': Timestamp('2015-01-05 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 36.1921,
#   'longitude': -86.7426,
#   'year': '2015',
#   'combined': (36.1921, -86.7426)},
#  {'incident_id': 277311,
#   'date': Timestamp('2015-01-05 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 35.0521,
#   'longitude': -89.98100000000001,
#   'year': '2015',
#   'combined': (35.0521, -89.98100000000001)},
#  {'incident_id': 274928,
#   'date': Timestamp('2015-01-05 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 40.4412,
#   'longitude': -79.9712,
#   'year': '2015',
#   'combined': (40.4412, -79.9712)},
#  {'incident_id': 273813,
#   'date': Timestamp('2015-01-05 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 37.2904,
#   'longitude': -120.49700000000001,
#   'year': '2015',
#   'combined': (37.2904, -120.49700000000001)},
#  {'incident_id': 277006,
#   'date': Timestamp('2015-01-05 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 34.5849,
#   'longitude': -118.12100000000001,
#   'year': '2015',
#   'combined': (34.5849, -118.12100000000001)},
#  {'incident_id': 274950,
#   'date': Timestamp('2015-01-05 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 40.2589,
#   'longitude': -76.5161,
#   'year': '2015',
#   'combined': (40.2589, -76.5161)},
#  {'incident_id': 274412,
#   'date': Timestamp('2015-01-05 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 33.7919,
#   'longitude': -118.198,
#   'year': '2015',
#   'combined': (33.7919, -118.198)},
#  {'incident_id': 274386,
#   'date': Timestamp('2015-01-05 00:00:00'),
#   'state': 'California',
#   'n_killed': 3,
#   'n_injured': 0,
#   'latitude': 36.5658,
#   'longitude': -119.62100000000001,
#   'year': '2015',
#   'combined': (36.5658, -119.62100000000001)},
#  {'incident_id': 274385,
#   'date': Timestamp('2015-01-05 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 36.7685,
#   'longitude': -119.804,
#   'year': '2015',
#   'combined': (36.7685, -119.804)},
#  {'incident_id': 274970,
#   'date': Timestamp('2015-01-06 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 34.5145,
#   'longitude': -117.303,
#   'year': '2015',
#   'combined': (34.5145, -117.303)},
#  {'incident_id': 274401,
#   'date': Timestamp('2015-01-06 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 34.1597,
#   'longitude': -118.148,
#   'year': '2015',
#   'combined': (34.1597, -118.148)},
#  {'incident_id': 519742,
#   'date': Timestamp('2015-01-06 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 40.368,
#   'longitude': -79.8939,
#   'year': '2015',
#   'combined': (40.368, -79.8939)},
#  {'incident_id': 274951,
#   'date': Timestamp('2015-01-06 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 40.4134,
#   'longitude': -79.9914,
#   'year': '2015',
#   'combined': (40.4134, -79.9914)},
#  {'incident_id': 791137,
#   'date': Timestamp('2015-01-06 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 37.9304,
#   'longitude': -121.291,
#   'year': '2015',
#   'combined': (37.9304, -121.291)},
#  {'incident_id': 275091,
#   'date': Timestamp('2015-01-06 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 35.2075,
#   'longitude': -89.9943,
#   'year': '2015',
#   'combined': (35.2075, -89.9943)},
#  {'incident_id': 275072,
#   'date': Timestamp('2015-01-06 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 35.0137,
#   'longitude': -85.2823,
#   'year': '2015',
#   'combined': (35.0137, -85.2823)},
#  {'incident_id': 274605,
#   'date': Timestamp('2015-01-06 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 35.9727,
#   'longitude': -83.9074,
#   'year': '2015',
#   'combined': (35.9727, -83.9074)},
#  {'incident_id': 275034,
#   'date': Timestamp('2015-01-06 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 37.696999999999996,
#   'longitude': -122.126,
#   'year': '2015',
#   'combined': (37.696999999999996, -122.126)},
#  {'incident_id': 277318,
#   'date': Timestamp('2015-01-06 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 37.3715,
#   'longitude': -121.93,
#   'year': '2015',
#   'combined': (37.3715, -121.93)},
#  {'incident_id': 275627,
#   'date': Timestamp('2015-01-06 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 39.6313,
#   'longitude': -121.432,
#   'year': '2015',
#   'combined': (39.6313, -121.432)},
#  {'incident_id': 275639,
#   'date': Timestamp('2015-01-06 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 36.0875,
#   'longitude': -119.03,
#   'year': '2015',
#   'combined': (36.0875, -119.03)},
#  {'incident_id': 274597,
#   'date': Timestamp('2015-01-06 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 35.1068,
#   'longitude': -89.9489,
#   'year': '2015',
#   'combined': (35.1068, -89.9489)},
#  {'incident_id': 275040,
#   'date': Timestamp('2015-01-07 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 35.3793,
#   'longitude': -118.97,
#   'year': '2015',
#   'combined': (35.3793, -118.97)},
#  {'incident_id': 275031,
#   'date': Timestamp('2015-01-07 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 36.1516,
#   'longitude': -86.7566,
#   'year': '2015',
#   'combined': (36.1516, -86.7566)},
#  {'incident_id': 275074,
#   'date': Timestamp('2015-01-07 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 35.1402,
#   'longitude': -85.2397,
#   'year': '2015',
#   'combined': (35.1402, -85.2397)},
#  {'incident_id': 275695,
#   'date': Timestamp('2015-01-07 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 35.1661,
#   'longitude': -89.9509,
#   'year': '2015',
#   'combined': (35.1661, -89.9509)},
#  {'incident_id': 275539,
#   'date': Timestamp('2015-01-07 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 35.1197,
#   'longitude': -85.0838,
#   'year': '2015',
#   'combined': (35.1197, -85.0838)},
#  {'incident_id': 275643,
#   'date': Timestamp('2015-01-07 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 33.8247,
#   'longitude': -117.99799999999999,
#   'year': '2015',
#   'combined': (33.8247, -117.99799999999999)},
#  {'incident_id': 275093,
#   'date': Timestamp('2015-01-07 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 35.0469,
#   'longitude': -90.084,
#   'year': '2015',
#   'combined': (35.0469, -90.084)},
#  {'incident_id': 274969,
#   'date': Timestamp('2015-01-07 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 34.1016,
#   'longitude': -118.32799999999999,
#   'year': '2015',
#   'combined': (34.1016, -118.32799999999999)},
#  {'incident_id': 275027,
#   'date': Timestamp('2015-01-07 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 36.1647,
#   'longitude': -86.816,
#   'year': '2015',
#   'combined': (36.1647, -86.816)},
#  {'incident_id': 275882,
#   'date': Timestamp('2015-01-07 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 2,
#   'latitude': 33.9384,
#   'longitude': -116.885,
#   'year': '2015',
#   'combined': (33.9384, -116.885)},
#  {'incident_id': 276496,
#   'date': Timestamp('2015-01-07 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 40.9679,
#   'longitude': -75.9783,
#   'year': '2015',
#   'combined': (40.9679, -75.9783)},
#  {'incident_id': 275058,
#   'date': Timestamp('2015-01-07 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 38.6448,
#   'longitude': -121.066,
#   'year': '2015',
#   'combined': (38.6448, -121.066)},
#  {'incident_id': 275064,
#   'date': Timestamp('2015-01-07 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 1,
#   'n_injured': 3,
#   'latitude': 35.0403,
#   'longitude': -85.3182,
#   'year': '2015',
#   'combined': (35.0403, -85.3182)},
#  {'incident_id': 276997,
#   'date': Timestamp('2015-01-07 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 36.705,
#   'longitude': -121.65299999999999,
#   'year': '2015',
#   'combined': (36.705, -121.65299999999999)},
#  {'incident_id': 276494,
#   'date': Timestamp('2015-01-07 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 39.9345,
#   'longitude': -75.2167,
#   'year': '2015',
#   'combined': (39.9345, -75.2167)},
#  {'incident_id': 275872,
#   'date': Timestamp('2015-01-08 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 37.9656,
#   'longitude': -121.764,
#   'year': '2015',
#   'combined': (37.9656, -121.764)},
#  {'incident_id': 275885,
#   'date': Timestamp('2015-01-08 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 36.6802,
#   'longitude': -121.65,
#   'year': '2015',
#   'combined': (36.6802, -121.65)},
#  {'incident_id': 275877,
#   'date': Timestamp('2015-01-08 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 36.7286,
#   'longitude': -119.74600000000001,
#   'year': '2015',
#   'combined': (36.7286, -119.74600000000001)},
#  {'incident_id': 275879,
#   'date': Timestamp('2015-01-08 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 37.9295,
#   'longitude': -122.331,
#   'year': '2015',
#   'combined': (37.9295, -122.331)},
#  {'incident_id': 275890,
#   'date': Timestamp('2015-01-08 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 36.9072,
#   'longitude': -121.775,
#   'year': '2015',
#   'combined': (36.9072, -121.775)},
#  {'incident_id': 275875,
#   'date': Timestamp('2015-01-08 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 36.7062,
#   'longitude': -119.76100000000001,
#   'year': '2015',
#   'combined': (36.7062, -119.76100000000001)},
#  {'incident_id': 276752,
#   'date': Timestamp('2015-01-08 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 39.9466,
#   'longitude': -75.2358,
#   'year': '2015',
#   'combined': (39.9466, -75.2358)},
#  {'incident_id': 277332,
#   'date': Timestamp('2015-01-08 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 36.1334,
#   'longitude': -86.6652,
#   'year': '2015',
#   'combined': (36.1334, -86.6652)},
#  {'incident_id': 275518,
#   'date': Timestamp('2015-01-08 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 35.0821,
#   'longitude': -89.913,
#   'year': '2015',
#   'combined': (35.0821, -89.913)},
#  {'incident_id': 277328,
#   'date': Timestamp('2015-01-08 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 34.0626,
#   'longitude': -117.59299999999999,
#   'year': '2015',
#   'combined': (34.0626, -117.59299999999999)},
#  {'incident_id': 276747,
#   'date': Timestamp('2015-01-08 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 40.4755,
#   'longitude': -76.7958,
#   'year': '2015',
#   'combined': (40.4755, -76.7958)},
#  {'incident_id': 276127,
#   'date': Timestamp('2015-01-08 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 35.4469,
#   'longitude': -84.6046,
#   'year': '2015',
#   'combined': (35.4469, -84.6046)},
#  {'incident_id': 275648,
#   'date': Timestamp('2015-01-08 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 34.1708,
#   'longitude': -117.322,
#   'year': '2015',
#   'combined': (34.1708, -117.322)},
#  {'incident_id': 275634,
#   'date': Timestamp('2015-01-08 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 36.7647,
#   'longitude': -119.844,
#   'year': '2015',
#   'combined': (36.7647, -119.844)},
#  {'incident_id': 275622,
#   'date': Timestamp('2015-01-08 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 36.1995,
#   'longitude': -86.3051,
#   'year': '2015',
#   'combined': (36.1995, -86.3051)},
#  {'incident_id': 275630,
#   'date': Timestamp('2015-01-08 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 40.7641,
#   'longitude': -124.147,
#   'year': '2015',
#   'combined': (40.7641, -124.147)},
#  {'incident_id': 276108,
#   'date': Timestamp('2015-01-08 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 36.2207,
#   'longitude': -86.8229,
#   'year': '2015',
#   'combined': (36.2207, -86.8229)},
#  {'incident_id': 279813,
#   'date': Timestamp('2015-01-08 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 39.8903,
#   'longitude': -75.2773,
#   'year': '2015',
#   'combined': (39.8903, -75.2773)},
#  {'incident_id': 276555,
#   'date': Timestamp('2015-01-08 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 37.3001,
#   'longitude': -120.46,
#   'year': '2015',
#   'combined': (37.3001, -120.46)},
#  {'incident_id': 276231,
#   'date': Timestamp('2015-01-09 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 1,
#   'n_injured': 2,
#   'latitude': 35.1047,
#   'longitude': -89.9746,
#   'year': '2015',
#   'combined': (35.1047, -89.9746)},
#  {'incident_id': 276748,
#   'date': Timestamp('2015-01-09 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 40.1176,
#   'longitude': -75.0145,
#   'year': '2015',
#   'combined': (40.1176, -75.0145)},
#  {'incident_id': 276995,
#   'date': Timestamp('2015-01-09 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 36.6936,
#   'longitude': -121.61,
#   'year': '2015',
#   'combined': (36.6936, -121.61)},
#  {'incident_id': 279599,
#   'date': Timestamp('2015-01-09 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 40.3415,
#   'longitude': -76.42399999999999,
#   'year': '2015',
#   'combined': (40.3415, -76.42399999999999)},
#  {'incident_id': 276659,
#   'date': Timestamp('2015-01-09 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 0,
#   'n_injured': 3,
#   'latitude': 41.1007,
#   'longitude': -75.3356,
#   'year': '2015',
#   'combined': (41.1007, -75.3356)},
#  {'incident_id': 276459,
#   'date': Timestamp('2015-01-09 00:00:00'),
#   'state': 'California',
#   'n_killed': 4,
#   'n_injured': 0,
#   'latitude': 37.7737,
#   'longitude': -122.426,
#   'year': '2015',
#   'combined': (37.7737, -122.426)},
#  {'incident_id': 276582,
#   'date': Timestamp('2015-01-09 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 2,
#   'latitude': 33.9224,
#   'longitude': -118.12100000000001,
#   'year': '2015',
#   'combined': (33.9224, -118.12100000000001)},
#  {'incident_id': 276571,
#   'date': Timestamp('2015-01-09 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 38.6187,
#   'longitude': -121.45700000000001,
#   'year': '2015',
#   'combined': (38.6187, -121.45700000000001)},
#  {'incident_id': 276532,
#   'date': Timestamp('2015-01-09 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 2,
#   'latitude': 35.2378,
#   'longitude': -118.941,
#   'year': '2015',
#   'combined': (35.2378, -118.941)},
#  {'incident_id': 276844,
#   'date': Timestamp('2015-01-09 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 36.6932,
#   'longitude': -121.611,
#   'year': '2015',
#   'combined': (36.6932, -121.611)},
#  {'incident_id': 276113,
#   'date': Timestamp('2015-01-09 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 36.1872,
#   'longitude': -86.7709,
#   'year': '2015',
#   'combined': (36.1872, -86.7709)},
#  {'incident_id': 276118,
#   'date': Timestamp('2015-01-09 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 35.6932,
#   'longitude': -88.8579,
#   'year': '2015',
#   'combined': (35.6932, -88.8579)},
#  {'incident_id': 276405,
#   'date': Timestamp('2015-01-09 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 1,
#   'n_injured': 1,
#   'latitude': 36.5535,
#   'longitude': -82.6356,
#   'year': '2015',
#   'combined': (36.5535, -82.6356)},
#  {'incident_id': 464046,
#   'date': Timestamp('2015-01-09 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 41.2283,
#   'longitude': -75.902,
#   'year': '2015',
#   'combined': (41.2283, -75.902)},
#  {'incident_id': 277002,
#   'date': Timestamp('2015-01-09 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 36.5394,
#   'longitude': -119.296,
#   'year': '2015',
#   'combined': (36.5394, -119.296)},
#  {'incident_id': 276668,
#   'date': Timestamp('2015-01-09 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 40.2594,
#   'longitude': -76.8627,
#   'year': '2015',
#   'combined': (40.2594, -76.8627)},
#  {'incident_id': 276670,
#   'date': Timestamp('2015-01-09 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 39.9608,
#   'longitude': -75.2331,
#   'year': '2015',
#   'combined': (39.9608, -75.2331)},
#  {'incident_id': 276993,
#   'date': Timestamp('2015-01-10 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 36.6797,
#   'longitude': -121.655,
#   'year': '2015',
#   'combined': (36.6797, -121.655)},
#  {'incident_id': 276858,
#   'date': Timestamp('2015-01-10 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 2,
#   'latitude': 33.129,
#   'longitude': -117.07700000000001,
#   'year': '2015',
#   'combined': (33.129, -117.07700000000001)},
#  {'incident_id': 283607,
#   'date': Timestamp('2015-01-10 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 33.9872,
#   'longitude': -118.331,
#   'year': '2015',
#   'combined': (33.9872, -118.331)},
#  {'incident_id': 276423,
#   'date': Timestamp('2015-01-10 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 1,
#   'latitude': 33.9553,
#   'longitude': -118.348,
#   'year': '2015',
#   'combined': (33.9553, -118.348)},
#  {'incident_id': 277087,
#   'date': Timestamp('2015-01-10 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 33.9225,
#   'longitude': -118.271,
#   'year': '2015',
#   'combined': (33.9225, -118.271)},
#  {'incident_id': 276784,
#   'date': Timestamp('2015-01-10 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 34.0318,
#   'longitude': -117.552,
#   'year': '2015',
#   'combined': (34.0318, -117.552)},
#  {'incident_id': 277251,
#   'date': Timestamp('2015-01-10 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 36.2151,
#   'longitude': -121.13,
#   'year': '2015',
#   'combined': (36.2151, -121.13)},
#  {'incident_id': 276553,
#   'date': Timestamp('2015-01-10 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 33.8128,
#   'longitude': -118.111,
#   'year': '2015',
#   'combined': (33.8128, -118.111)},
#  {'incident_id': 277043,
#   'date': Timestamp('2015-01-10 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 39.9355,
#   'longitude': -75.223,
#   'year': '2015',
#   'combined': (39.9355, -75.223)},
#  {'incident_id': 276985,
#   'date': Timestamp('2015-01-10 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 33.9089,
#   'longitude': -118.148,
#   'year': '2015',
#   'combined': (33.9089, -118.148)},
#  {'incident_id': 277249,
#   'date': Timestamp('2015-01-10 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 34.0318,
#   'longitude': -117.552,
#   'year': '2015',
#   'combined': (34.0318, -117.552)},
#  {'incident_id': 276977,
#   'date': Timestamp('2015-01-10 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 37.9587,
#   'longitude': -122.365,
#   'year': '2015',
#   'combined': (37.9587, -122.365)},
#  {'incident_id': 277504,
#   'date': Timestamp('2015-01-10 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 38.0825,
#   'longitude': -122.227,
#   'year': '2015',
#   'combined': (38.0825, -122.227)},
#  {'incident_id': 276787,
#   'date': Timestamp('2015-01-10 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 3,
#   'n_injured': 0,
#   'latitude': 40.0326,
#   'longitude': -75.0322,
#   'year': '2015',
#   'combined': (40.0326, -75.0322)},
#  {'incident_id': 281424,
#   'date': Timestamp('2015-01-10 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 36.6108,
#   'longitude': -121.84299999999999,
#   'year': '2015',
#   'combined': (36.6108, -121.84299999999999)},
#  {'incident_id': 276403,
#   'date': Timestamp('2015-01-10 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 36.3499,
#   'longitude': -82.3832,
#   'year': '2015',
#   'combined': (36.3499, -82.3832)},
#  {'incident_id': 276772,
#   'date': Timestamp('2015-01-10 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 37.3417,
#   'longitude': -121.861,
#   'year': '2015',
#   'combined': (37.3417, -121.861)},
#  {'incident_id': 277781,
#   'date': Timestamp('2015-01-10 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 39.9078,
#   'longitude': -75.1386,
#   'year': '2015',
#   'combined': (39.9078, -75.1386)},
#  {'incident_id': 277246,
#   'date': Timestamp('2015-01-11 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 2,
#   'latitude': 33.7844,
#   'longitude': -118.164,
#   'year': '2015',
#   'combined': (33.7844, -118.164)},
#  {'incident_id': 276987,
#   'date': Timestamp('2015-01-11 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 37.3501,
#   'longitude': -120.58,
#   'year': '2015',
#   'combined': (37.3501, -120.58)},
#  {'incident_id': 276794,
#   'date': Timestamp('2015-01-11 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 0,
#   'n_injured': 3,
#   'latitude': 40.0221,
#   'longitude': -75.1534,
#   'year': '2015',
#   'combined': (40.0221, -75.1534)},
#  {'incident_id': 277235,
#   'date': Timestamp('2015-01-11 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 37.7623,
#   'longitude': -122.18799999999999,
#   'year': '2015',
#   'combined': (37.7623, -122.18799999999999)},
#  {'incident_id': 277232,
#   'date': Timestamp('2015-01-11 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 2,
#   'latitude': 37.8116,
#   'longitude': -122.28200000000001,
#   'year': '2015',
#   'combined': (37.8116, -122.28200000000001)},
#  {'incident_id': 276779,
#   'date': Timestamp('2015-01-11 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 33.9525,
#   'longitude': -118.189,
#   'year': '2015',
#   'combined': (33.9525, -118.189)},
#  {'incident_id': 277670,
#   'date': Timestamp('2015-01-11 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 39.9778,
#   'longitude': -75.1835,
#   'year': '2015',
#   'combined': (39.9778, -75.1835)},
#  {'incident_id': 276766,
#   'date': Timestamp('2015-01-11 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 5,
#   'latitude': 37.2818,
#   'longitude': -121.839,
#   'year': '2015',
#   'combined': (37.2818, -121.839)},
#  {'incident_id': 277346,
#   'date': Timestamp('2015-01-11 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 36.3267,
#   'longitude': -86.7078,
#   'year': '2015',
#   'combined': (36.3267, -86.7078)},
#  {'incident_id': 277354,
#   'date': Timestamp('2015-01-11 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 35.1015,
#   'longitude': -89.8332,
#   'year': '2015',
#   'combined': (35.1015, -89.8332)},
#  {'incident_id': 280714,
#   'date': Timestamp('2015-01-11 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 36.1334,
#   'longitude': -86.6652,
#   'year': '2015',
#   'combined': (36.1334, -86.6652)},
#  {'incident_id': 277358,
#   'date': Timestamp('2015-01-11 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 35.6324,
#   'longitude': -88.7995,
#   'year': '2015',
#   'combined': (35.6324, -88.7995)},
#  {'incident_id': 277091,
#   'date': Timestamp('2015-01-11 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 36.1822,
#   'longitude': -86.8144,
#   'year': '2015',
#   'combined': (36.1822, -86.8144)},
#  {'incident_id': 276885,
#   'date': Timestamp('2015-01-11 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 37.9664,
#   'longitude': -122.505,
#   'year': '2015',
#   'combined': (37.9664, -122.505)},
#  {'incident_id': 277226,
#   'date': Timestamp('2015-01-11 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 37.8237,
#   'longitude': -122.262,
#   'year': '2015',
#   'combined': (37.8237, -122.262)},
#  {'incident_id': 277507,
#   'date': Timestamp('2015-01-12 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 2,
#   'latitude': 37.7828,
#   'longitude': -122.414,
#   'year': '2015',
#   'combined': (37.7828, -122.414)},
#  {'incident_id': 284392,
#   'date': Timestamp('2015-01-12 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 40.5681,
#   'longitude': -76.7036,
#   'year': '2015',
#   'combined': (40.5681, -76.7036)},
#  {'incident_id': 283595,
#   'date': Timestamp('2015-01-12 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 33.9234,
#   'longitude': -118.272,
#   'year': '2015',
#   'combined': (33.9234, -118.272)},
#  {'incident_id': 278412,
#   'date': Timestamp('2015-01-12 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 35.4594,
#   'longitude': -84.6352,
#   'year': '2015',
#   'combined': (35.4594, -84.6352)},
#  {'incident_id': 277929,
#   'date': Timestamp('2015-01-12 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 35.611999999999995,
#   'longitude': -88.8172,
#   'year': '2015',
#   'combined': (35.611999999999995, -88.8172)},
#  {'incident_id': 277941,
#   'date': Timestamp('2015-01-12 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 35.4013,
#   'longitude': -85.6846,
#   'year': '2015',
#   'combined': (35.4013, -85.6846)},
#  {'incident_id': 277806,
#   'date': Timestamp('2015-01-12 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 36.6807,
#   'longitude': -121.605,
#   'year': '2015',
#   'combined': (36.6807, -121.605)},
#  {'incident_id': 277801,
#   'date': Timestamp('2015-01-12 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 34.0026,
#   'longitude': -118.321,
#   'year': '2015',
#   'combined': (34.0026, -118.321)},
#  {'incident_id': 277797,
#   'date': Timestamp('2015-01-12 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 34.1213,
#   'longitude': -117.30799999999999,
#   'year': '2015',
#   'combined': (34.1213, -117.30799999999999)},
#  {'incident_id': 281453,
# ...
#   'longitude': -84.2348,
#   'year': '2015',
#   'combined': (36.2206, -84.2348)},
#  {'incident_id': 299362,
#   'date': Timestamp('2015-02-28 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 37.7908,
#   'longitude': -122.212,
#   'year': '2015',
#   'combined': (37.7908, -122.212)},
#  {'incident_id': 299327,
#   'date': Timestamp('2015-02-28 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 2,
#   'latitude': 34.1551,
#   'longitude': -119.171,
#   'year': '2015',
#   'combined': (34.1551, -119.171)},
#  {'incident_id': 910432,
#   'date': Timestamp('2015-02-28 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 34.0444,
#   'longitude': -118.195,
#   'year': '2015',
#   'combined': (34.0444, -118.195)},
#  {'incident_id': 302277,
#   'date': Timestamp('2015-02-28 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 39.9049,
#   'longitude': -75.2399,
#   'year': '2015',
#   'combined': (39.9049, -75.2399)},
#  {'incident_id': 299210,
#   'date': Timestamp('2015-02-28 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 41.2222,
#   'longitude': -80.5028,
#   'year': '2015',
#   'combined': (41.2222, -80.5028)},
#  {'incident_id': 299371,
#   'date': Timestamp('2015-02-28 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 37.7534,
#   'longitude': -122.177,
#   'year': '2015',
#   'combined': (37.7534, -122.177)},
#  {'incident_id': 299664,
#   'date': Timestamp('2015-02-28 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 33.7417,
#   'longitude': -117.896,
#   'year': '2015',
#   'combined': (33.7417, -117.896)},
#  {'incident_id': 306419,
#   'date': Timestamp('2015-02-28 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 36.3483,
#   'longitude': -82.1996,
#   'year': '2015',
#   'combined': (36.3483, -82.1996)},
#  {'incident_id': 299358,
#   'date': Timestamp('2015-02-28 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 37.7566,
#   'longitude': -122.196,
#   'year': '2015',
#   'combined': (37.7566, -122.196)},
#  {'incident_id': 299971,
#   'date': Timestamp('2015-02-28 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 40.9621,
#   'longitude': -75.9618,
#   'year': '2015',
#   'combined': (40.9621, -75.9618)},
#  {'incident_id': 299082,
#   'date': Timestamp('2015-02-28 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 2,
#   'n_injured': 0,
#   'latitude': 35.6011,
#   'longitude': -88.0215,
#   'year': '2015',
#   'combined': (35.6011, -88.0215)},
#  {'incident_id': 306715,
#   'date': Timestamp('2015-02-28 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 35.1554,
#   'longitude': -89.9561,
#   'year': '2015',
#   'combined': (35.1554, -89.9561)},
#  {'incident_id': 299382,
#   'date': Timestamp('2015-02-28 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 36.7468,
#   'longitude': -119.773,
#   'year': '2015',
#   'combined': (36.7468, -119.773)},
#  {'incident_id': 299874,
#   'date': Timestamp('2015-03-01 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 35.0472,
#   'longitude': -85.2674,
#   'year': '2015',
#   'combined': (35.0472, -85.2674)},
#  {'incident_id': 299857,
#   'date': Timestamp('2015-03-01 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 2,
#   'latitude': 35.0617,
#   'longitude': -90.0307,
#   'year': '2015',
#   'combined': (35.0617, -90.0307)},
#  {'incident_id': 299852,
#   'date': Timestamp('2015-03-01 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 35.0678,
#   'longitude': -89.9436,
#   'year': '2015',
#   'combined': (35.0678, -89.9436)},
#  {'incident_id': 300493,
#   'date': Timestamp('2015-03-01 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 35.6571,
#   'longitude': -88.85600000000001,
#   'year': '2015',
#   'combined': (35.6571, -88.85600000000001)},
#  {'incident_id': 299834,
#   'date': Timestamp('2015-03-01 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 2,
#   'latitude': 35.0567,
#   'longitude': -90.0598,
#   'year': '2015',
#   'combined': (35.0567, -90.0598)},
#  {'incident_id': 299979,
#   'date': Timestamp('2015-03-01 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 40.4509,
#   'longitude': -79.9849,
#   'year': '2015',
#   'combined': (40.4509, -79.9849)},
#  {'incident_id': 299367,
#   'date': Timestamp('2015-03-01 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 37.6612,
#   'longitude': -122.089,
#   'year': '2015',
#   'combined': (37.6612, -122.089)},
#  {'incident_id': 299674,
#   'date': Timestamp('2015-03-01 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 36.7577,
#   'longitude': -119.75200000000001,
#   'year': '2015',
#   'combined': (36.7577, -119.75200000000001)},
#  {'incident_id': 299661,
#   'date': Timestamp('2015-03-01 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 2,
#   'latitude': 37.8109,
#   'longitude': -122.277,
#   'year': '2015',
#   'combined': (37.8109, -122.277)},
#  {'incident_id': 299656,
#   'date': Timestamp('2015-03-01 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 1,
#   'latitude': 34.1021,
#   'longitude': -117.741,
#   'year': '2015',
#   'combined': (34.1021, -117.741)},
#  {'incident_id': 299336,
#   'date': Timestamp('2015-03-01 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 1,
#   'n_injured': 1,
#   'latitude': 36.1528,
#   'longitude': -86.7962,
#   'year': '2015',
#   'combined': (36.1528, -86.7962)},
#  {'incident_id': 299981,
#   'date': Timestamp('2015-03-01 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 40.4208,
#   'longitude': -79.9958,
#   'year': '2015',
#   'combined': (40.4208, -79.9958)},
#  {'incident_id': 299322,
#   'date': Timestamp('2015-03-01 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 34.0424,
#   'longitude': -118.245,
#   'year': '2015',
#   'combined': (34.0424, -118.245)},
#  {'incident_id': 299584,
#   'date': Timestamp('2015-03-01 00:00:00'),
#   'state': 'California',
#   'n_killed': 2,
#   'n_injured': 0,
#   'latitude': 37.7216,
#   'longitude': -121.714,
#   'year': '2015',
#   'combined': (37.7216, -121.714)},
#  {'incident_id': 299672,
#   'date': Timestamp('2015-03-01 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 37.1179,
#   'longitude': -120.256,
#   'year': '2015',
#   'combined': (37.1179, -120.256)},
#  {'incident_id': 302301,
#   'date': Timestamp('2015-03-01 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 35.0521,
#   'longitude': -89.98100000000001,
#   'year': '2015',
#   'combined': (35.0521, -89.98100000000001)},
#  {'incident_id': 299324,
#   'date': Timestamp('2015-03-01 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 1,
#   'latitude': 34.2028,
#   'longitude': -119.161,
#   'year': '2015',
#   'combined': (34.2028, -119.161)},
#  {'incident_id': 299587,
#   'date': Timestamp('2015-03-01 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 2,
#   'latitude': 37.9341,
#   'longitude': -122.355,
#   'year': '2015',
#   'combined': (37.9341, -122.355)},
#  {'incident_id': 299594,
#   'date': Timestamp('2015-03-01 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 2,
#   'latitude': 36.0741,
#   'longitude': -86.6896,
#   'year': '2015',
#   'combined': (36.0741, -86.6896)},
#  {'incident_id': 299602,
#   'date': Timestamp('2015-03-01 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 37.6404,
#   'longitude': -120.615,
#   'year': '2015',
#   'combined': (37.6404, -120.615)},
#  {'incident_id': 301150,
#   'date': Timestamp('2015-03-02 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 36.8408,
#   'longitude': -119.79899999999999,
#   'year': '2015',
#   'combined': (36.8408, -119.79899999999999)},
#  {'incident_id': 302535,
#   'date': Timestamp('2015-03-02 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 37.3715,
#   'longitude': -121.93,
#   'year': '2015',
#   'combined': (37.3715, -121.93)},
#  {'incident_id': 302303,
#   'date': Timestamp('2015-03-02 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 36.1334,
#   'longitude': -86.6652,
#   'year': '2015',
#   'combined': (36.1334, -86.6652)},
#  {'incident_id': 302302,
#   'date': Timestamp('2015-03-02 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 36.481,
#   'longitude': -82.40799999999999,
#   'year': '2015',
#   'combined': (36.481, -82.40799999999999)},
#  {'incident_id': 300929,
#   'date': Timestamp('2015-03-02 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 33.6962,
#   'longitude': -117.771,
#   'year': '2015',
#   'combined': (33.6962, -117.771)},
#  {'incident_id': 299670,
#   'date': Timestamp('2015-03-02 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 37.7699,
#   'longitude': -121.205,
#   'year': '2015',
#   'combined': (37.7699, -121.205)},
#  {'incident_id': 299659,
#   'date': Timestamp('2015-03-02 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 37.8079,
#   'longitude': -122.272,
#   'year': '2015',
#   'combined': (37.8079, -122.272)},
#  {'incident_id': 299666,
#   'date': Timestamp('2015-03-02 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 2,
#   'latitude': 33.7479,
#   'longitude': -117.834,
#   'year': '2015',
#   'combined': (33.7479, -117.834)},
#  {'incident_id': 300848,
#   'date': Timestamp('2015-03-02 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 38.0003,
#   'longitude': -121.845,
#   'year': '2015',
#   'combined': (38.0003, -121.845)},
#  {'incident_id': 301934,
#   'date': Timestamp('2015-03-02 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 36.6662,
#   'longitude': -121.654,
#   'year': '2015',
#   'combined': (36.6662, -121.654)},
#  {'incident_id': 302400,
#   'date': Timestamp('2015-03-02 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 36.0605,
#   'longitude': -86.5903,
#   'year': '2015',
#   'combined': (36.0605, -86.5903)},
#  {'incident_id': 299862,
#   'date': Timestamp('2015-03-02 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 36.3522,
#   'longitude': -82.3536,
#   'year': '2015',
#   'combined': (36.3522, -82.3536)},
#  {'incident_id': 300629,
#   'date': Timestamp('2015-03-02 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 40.6776,
#   'longitude': -76.2139,
#   'year': '2015',
#   'combined': (40.6776, -76.2139)},
#  {'incident_id': 300984,
#   'date': Timestamp('2015-03-02 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 40.3532,
#   'longitude': -122.321,
#   'year': '2015',
#   'combined': (40.3532, -122.321)},
#  {'incident_id': 300491,
#   'date': Timestamp('2015-03-02 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 35.5524,
#   'longitude': -89.2449,
#   'year': '2015',
#   'combined': (35.5524, -89.2449)},
#  {'incident_id': 300917,
#   'date': Timestamp('2015-03-02 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 35.0719,
#   'longitude': -85.3038,
#   'year': '2015',
#   'combined': (35.0719, -85.3038)},
#  {'incident_id': 300513,
#   'date': Timestamp('2015-03-02 00:00:00'),
#   'state': 'Pennsylvania',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 39.9556,
#   'longitude': -76.7514,
#   'year': '2015',
#   'combined': (39.9556, -76.7514)},
#  {'incident_id': 299881,
#   'date': Timestamp('2015-03-02 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 35.0108,
#   'longitude': -85.2763,
#   'year': '2015',
#   'combined': (35.0108, -85.2763)},
#  {'incident_id': 299849,
#   'date': Timestamp('2015-03-02 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 2,
#   'latitude': 35.1991,
#   'longitude': -89.9446,
#   'year': '2015',
#   'combined': (35.1991, -89.9446)},
#  {'incident_id': 300911,
#   'date': Timestamp('2015-03-03 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 36.0074,
#   'longitude': -83.8738,
#   'year': '2015',
#   'combined': (36.0074, -83.8738)},
#  {'incident_id': 300487,
#   'date': Timestamp('2015-03-03 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 0,
#   'n_injured': 2,
#   'latitude': 36.2341,
#   'longitude': -86.7681,
#   'year': '2015',
#   'combined': (36.2341, -86.7681)},
#  {'incident_id': 300846,
#   'date': Timestamp('2015-03-03 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 33.8337,
#   'longitude': -118.068,
#   'year': '2015',
#   'combined': (33.8337, -118.068)},
#  {'incident_id': 300946,
#   'date': Timestamp('2015-03-03 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 37.2914,
#   'longitude': -120.5,
#   'year': '2015',
#   'combined': (37.2914, -120.5)},
#  {'incident_id': 300945,
#   'date': Timestamp('2015-03-03 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 37.2896,
#   'longitude': -120.505,
#   'year': '2015',
#   'combined': (37.2896, -120.505)},
#  {'incident_id': 300941,
#   'date': Timestamp('2015-03-03 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 34.0495,
#   'longitude': -118.204,
#   'year': '2015',
#   'combined': (34.0495, -118.204)},
#  {'incident_id': 302228,
#   'date': Timestamp('2015-03-03 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 37.3378,
#   'longitude': -121.94200000000001,
#   'year': '2015',
#   'combined': (37.3378, -121.94200000000001)},
#  {'incident_id': 301321,
#   'date': Timestamp('2015-03-03 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 33.976,
#   'longitude': -116.51899999999999,
#   'year': '2015',
#   'combined': (33.976, -116.51899999999999)},
#  {'incident_id': 300839,
#   'date': Timestamp('2015-03-03 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 2,
#   'latitude': 34.2048,
#   'longitude': -118.536,
#   'year': '2015',
#   'combined': (34.2048, -118.536)},
#  {'incident_id': 300841,
#   'date': Timestamp('2015-03-03 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 34.0344,
#   'longitude': -118.289,
#   'year': '2015',
#   'combined': (34.0344, -118.289)},
#  {'incident_id': 301368,
#   'date': Timestamp('2015-03-03 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 36.8408,
#   'longitude': -119.79899999999999,
#   'year': '2015',
#   'combined': (36.8408, -119.79899999999999)},
#  {'incident_id': 301366,
#   'date': Timestamp('2015-03-03 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 36.8408,
#   'longitude': -119.79899999999999,
#   'year': '2015',
#   'combined': (36.8408, -119.79899999999999)},
#  {'incident_id': 300496,
#   'date': Timestamp('2015-03-03 00:00:00'),
#   'state': 'Tennessee',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 35.1513,
#   'longitude': -89.9525,
#   'year': '2015',
#   'combined': (35.1513, -89.9525)},
#  {'incident_id': 300986,
#   'date': Timestamp('2015-03-03 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 1,
#   'latitude': 38.496,
#   'longitude': -121.462,
#   'year': '2015',
#   'combined': (38.496, -121.462)},
#  {'incident_id': 301370,
#   'date': Timestamp('2015-03-03 00:00:00'),
#   'state': 'California',
#   'n_killed': 1,
#   'n_injured': 0,
#   'latitude': 36.008,
#   'longitude': -120.141,
#   'year': '2015',
#   'combined': (36.008, -120.141)},
#  {'incident_id': 300445,
#   'date': Timestamp('2015-03-03 00:00:00'),
#   'state': 'California',
#   'n_killed': 0,
#   'n_injured': 0,
#   'latitude': 34.0194,
#   'longitude': -117.63600000000001,
#   'year': '2015',
#   'combined': (34.0194, -117.63600000000001)},
#  ...]

# %%
guns.insert_many(guns_df.to_dict('records'))
